# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# ## What is Pandas?
# A powerful library for data manipulation and analysis in Python.
# Built on top of Numpy, provides data structures like series and dataframe.

# %% [markdown]
# ## Why use Pandas?
# * Easy data cleaning and transformation.
# * Efficient handling of large datasets.
# * Integration with other python libraries.

# %%
print("Introduction to Pandas")
# Out:
# Introduction to Pandas

# %%
print(7)
# Out:
# 7

# %% [markdown]
# ## Install Pandas using:

# %%
# %conda install pandas

# %% [markdown]
# # Key data structures in Pandas
# * Series(One-dimensional)
# * Dataframe(Two-dimensional)

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4, 5],index = ['a', 'b', 'c', 'd', 'e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"names": ["John", "Paul", "George", "Ringo"], "age": [23, 45, 67, 89]})

# %%
df
# Out:
#     names  age
# 0    John   23
# 1    Paul   45
# 2  George   67
# 3   Ringo   89

# %%
df = pd.read_csv("filecsv.csv")

# %%
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
df.tail()
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 20119  2023                  all       All Industries  j_Grand_Total
# 20120  2023                  all       All Industries  j_Grand_Total
# 20121  2023                  all       All Industries  j_Grand_Total
# 20122  2023                  all       All Industries  j_Grand_Total
# 20123  2023                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 20119                 Total income   930995  DOLLARS(millions)
# 20120            Total expenditure   832964  DOLLARS(millions)
# 20121  Operating profit before tax   103616  DOLLARS(millions)
# 20122                 Total assets  2831894  DOLLARS(millions)
# 20123        Fixed tangible assets   681890  DOLLARS(millions)

# %%
df.describe()
# Out:
#               year
# count  20124.00000
# mean    2017.00000
# std        3.74175
# min     2011.00000
# 25%     2014.00000
# 50%     2017.00000
# 75%     2020.00000
# max     2023.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20124 entries, 0 to 20123
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  20124 non-null  int64
#  1   industry_code_ANZSIC  20124 non-null  object
#  2   industry_name_ANZSIC  20124 non-null  object
#  3   rme_size_grp          20124 non-null  object
#  4   variable              20124 non-null  object
#  5   value                 20124 non-null  object
#  6   unit                  20124 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Data Selection

# %%
type(df["year"])
# Out:
# pandas.core.series.Series

# %%
df[["value", "unit"]]
# Out:
#          value               unit
# 0        46134              COUNT
# 1            0              COUNT
# 2          279  DOLLARS(millions)
# 3         8187  DOLLARS(millions)
# 4         8866  DOLLARS(millions)
# ...        ...                ...
# 20119   930995  DOLLARS(millions)
# 20120   832964  DOLLARS(millions)
# 20121   103616  DOLLARS(millions)
# 20122  2831894  DOLLARS(millions)
# 20123   681890  DOLLARS(millions)
#
# [20124 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# year                                                 2011
# industry_code_ANZSIC                                    A
# industry_name_ANZSIC    Agriculture, Forestry and Fishing
# rme_size_grp                                          a_0
# variable                                    Activity unit
# value                                               46134
# unit                                                COUNT
# Name: 0, dtype: object

# %%
df2 = pd.read_csv("datacsv - Copy.csv")

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2.head()
# Out:
#      year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0  2011.0                    A  Agriculture, Forestry and Fishing
# 1  2011.0                    A  Agriculture, Forestry and Fishing
# 2  2011.0                    A  Agriculture, Forestry and Fishing
# 3  2011.0                  NaN  Agriculture, Forestry and Fishing
# 4  2011.0                    A  Agriculture, Forestry and Fishing
#
#   rme_size_grp                                              var  value  \
# 0          a_0                                    Activity unit  46134
# 1          a_0                           Rolling mean employees      0
# 2          a_0                                              NaN    279
# 3          NaN  Sales, government funding, grants and subsidies   8187
# 4          a_0                                     Total income   8866
#
#                 unit  zeros
# 0              COUNT      0
# 1              COUNT      0
# 2  DOLLARS(millions)      0
# ...

# %%
df2.dropna()
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# 7      2011.0                    A  Agriculture, Forestry and Fishing
# 9      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                          var    value               unit  \
# ...

# %%
df2.head()
# Out:
#      year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0  2011.0                    A  Agriculture, Forestry and Fishing
# 1  2011.0                    A  Agriculture, Forestry and Fishing
# 2  2011.0                    A  Agriculture, Forestry and Fishing
# 3  2011.0                  NaN  Agriculture, Forestry and Fishing
# 4  2011.0                    A  Agriculture, Forestry and Fishing
#
#   rme_size_grp                                              var  value  \
# 0          a_0                                    Activity unit  46134
# 1          a_0                           Rolling mean employees      0
# 2          a_0                                              NaN    279
# 3          NaN  Sales, government funding, grants and subsidies   8187
# 4          a_0                                     Total income   8866
#
#                 unit  zeros
# 0              COUNT      0
# 1              COUNT      0
# 2  DOLLARS(millions)      0
# ...

# %%
df2.fillna(0)
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                    0  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2.head()
# Out:
#      year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0  2011.0                    A  Agriculture, Forestry and Fishing
# 1  2011.0                    A  Agriculture, Forestry and Fishing
# 2  2011.0                    A  Agriculture, Forestry and Fishing
# 3  2011.0                  NaN  Agriculture, Forestry and Fishing
# 4  2011.0                    A  Agriculture, Forestry and Fishing
#
#   rme_size_grp                                              var  value  \
# 0          a_0                                    Activity unit  46134
# 1          a_0                           Rolling mean employees      0
# 2          a_0                                              NaN    279
# 3          NaN  Sales, government funding, grants and subsidies   8187
# 4          a_0                                     Total income   8866
#
#                 unit  zeros
# 0              COUNT      0
# 1              COUNT      0
# 2  DOLLARS(millions)      0
# ...

# %%
df2.rename(columns = {"variable": "var"})
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2.rename(columns = {"variable": "var"})
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20124 entries, 0 to 20123
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  20124 non-null  int64
#  1   industry_code_ANZSIC  20124 non-null  object
#  2   industry_name_ANZSIC  20124 non-null  object
#  3   rme_size_grp          20124 non-null  object
#  4   variable              20124 non-null  object
#  5   value                 20124 non-null  object
#  6   unit                  20124 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ MB

# %%
df2["year"] = df2["year"].astype("float")

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20124 entries, 0 to 20123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  20124 non-null  float64
#  1   industry_code_ANZSIC  20123 non-null  object
#  2   industry_name_ANZSIC  20122 non-null  object
#  3   rme_size_grp          20122 non-null  object
#  4   var                   20122 non-null  object
#  5   value                 20123 non-null  object
#  6   unit                  20124 non-null  object
#  7   zeros                 20124 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
df2["zeros"] = [0 for i in range(len(df2))]

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df2.to_csv("datacsv - export.csv", index = False)

# %%
df3 = pd.DataFrame({
    "names": ["John", "Paul", "George", "Ringo"],
    "age": [23, 45, 67, 89]})

# %%
df4 = pd.DataFrame({
    "names": ["Dhiraj", "Suraj", "Rahuk", "Dev"], 
    "age": [33, 76, 45, 56]})

# %%
df3
# Out:
#     names  age
# 0    John   23
# 1    Paul   45
# 2  George   67
# 3   Ringo   89

# %%
df4
# Out:
#     names  age
# 0  Dhiraj   33
# 1   Suraj   76
# 2   Rahuk   45
# 3     Dev   56

# %%
pd.concat([df3, df4])
# Out:
#     names  age
# 0    John   23
# 1    Paul   45
# 2  George   67
# 3   Ringo   89
# 0  Dhiraj   33
# 1   Suraj   76
# 2   Rahuk   45
# 3     Dev   56

# %%
df2
# Out:
#          year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011.0                    A  Agriculture, Forestry and Fishing
# 1      2011.0                    A  Agriculture, Forestry and Fishing
# 2      2011.0                    A  Agriculture, Forestry and Fishing
# 3      2011.0                  NaN  Agriculture, Forestry and Fishing
# 4      2011.0                    A  Agriculture, Forestry and Fishing
# ...       ...                  ...                                ...
# 20119  2023.0                  all                     All Industries
# 20120  2023.0                  all                     All Industries
# 20121  2023.0                  all                     All Industries
# 20122  2023.0                  all                     All Industries
# 20123  2023.0                  all                     All Industries
#
#         rme_size_grp                                              var  \
# ...

# %%
df3
# Out:
#     names  age
# 0    John   23
# 1    Paul   45
# 2  George   67
# 3   Ringo   89

# %%
df3 = pd.DataFrame({
    "names": ["John", "Paul", "George", "Ringo"],
    "age": [23, 45, 67, 89]})

# %%
df4 = pd.DataFrame({
    "names": ["John", "Paul", "George", "Ringo"],
    "roll": [333, 444, 445, 455]})

# %%
df3.merge(df4, on = "names")
# Out:
#     names  age  roll
# 0    John   23   333
# 1    Paul   45   444
# 2  George   67   445
# 3   Ringo   89   455

# %%
df3
# Out:
#     names  age
# 0    John   23
# 1    Paul   45
# 2  George   67
# 3   Ringo   89

# %%
df4
# Out:
#     names  roll
# 0    John   333
# 1    Paul   444
# 2  George   445
# 3   Ringo   455

# %%
df3.merge(df4, on = "names")
# Out:
#     names  age  roll
# 0    John   23   333
# 1    Paul   45   444
# 2  George   67   445
# 3   Ringo   89   455

# %%
pd.merge(df3, df4, on = "names")
# Out:
#     names  age  roll
# 0    John   23   333
# 1    Paul   45   444
# 2  George   67   445
# 3   Ringo   89   455

# %%
pd.merge(df3, df4, on = "names")
# Out:
#     names  age  roll
# 0    John   23   333
# 1    Paul   45   444
# 2  George   67   445
# 3   Ringo   89   455
